# %%
# Dependencies
import requests
import pandas as pd
import json
from pprint import pprint
import plotly
import plotly.plotly as py
from plotly.graph_objs import *

import numpy as np
import requests
import copy
import googlemaps

# add your google maps api key here
my_google_maps_api_key = 'AIzaSyBUxB25CzI5dt30Oihdj1wfm-P10xaRGf0'

# %%
data = json.load(open('https://gist.githubusercontent.com/tdreyno/4278655/raw/7b0762c09b519f40397e4c3e100b097d861f5588/airports.json'))
pprint(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-1e710390bbcf> in <module>()
# ----> 1 data = json.load(open('https://gist.githubusercontent.com/tdreyno/4278655/raw/7b0762c09b519f40397e4c3e100b097d861f5588/airports.json'))
#       2 pprint(data)
#
# OSError: [Errno 22] Invalid argument: 'https://gist.githubusercontent.com/tdreyno/4278655/raw/7b0762c09b519f40397e4c3e100b097d861f5588/airports.json'

# %%
print(data[0]['lat']+ " , " + data[0]['lon'])
# Out:
# -17.3595 , -145.494

# %%
lat_lon_airport = {}

for airport_dictionary in data:
    '''
    To "append" to a dictionary, do the following:
    some_dict = {}
    #Add a new key : value pair
    some_dict['new_key'] = 'new_value'
    '''
    lat_lon_airport[airport_dictionary['code']] = [airport_dictionary['lat']+" , "+airport_dictionary['lon']]

# %%
lat_lon_airport
# Out:
# {'AAA': ['-17.3595 , -145.494'],
#  'AAE': ['36.8236 , 7.8103'],
#  'AAL': ['57.0952 , 9.85606'],
#  'AAM': ['-24.8 , 31.5333'],
#  'AAN': ['24.25 , 55.75'],
#  'AAQ': ['44.9 , 37.3167'],
#  'AAR': ['56.3088 , 10.6154'],
#  'AAT': ['47.7406 , 88.0845'],
#  'AAX': ['-19.5603 , -46.9653'],
#  'AAY': ['16.1947 , 52.1694'],
#  'ABA': ['53.7167 , 91.4333'],
#  'ABC': ['38.9833 , -1.85'],
#  'ABD': ['30.3374 , 48.3032'],
#  'ABE': ['40.6514 , -75.4342'],
#  'ABI': ['32.4164 , -99.6803'],
#  'ABJ': ['5.2556 , -3.9292'],
#  'ABK': ['6.73719 , 44.2797'],
#  'ABL': ['67.1058 , -157.854'],
#  'ABM': ['-10.9438 , 142.453'],
#  'ABQ': ['35.0494 , -106.625'],
#  'ABR': ['45.4536 , -98.4189'],
#  'ABS': ['22.3722 , 31.6125'],
#  'ABT': ['20.2961 , 41.6342'],
#  'ABV': ['9.0056 , 7.2661'],
#  'ABX': ['-36.0678 , 146.956'],
#  'ABY': ['31.5328 , -84.1867'],
#  'ABZ': ['57.2004 , -2.20373'],
#  'ACA': ['16.7561 , -99.7536'],
#  'ACC': ['5.5964 , -0.17'],
#  'ACE': ['28.9521 , -13.6085'],
# ...

# %%
for key in lat_lon_airport.keys():
    print(lat_lon_airport[key])
# Out:
# ['-17.3595 , -145.494']
# ['36.8236 , 7.8103']
# ['57.0952 , 9.85606']
# ['-24.8 , 31.5333']
# ['24.25 , 55.75']
# ['44.9 , 37.3167']
# ['56.3088 , 10.6154']
# ['47.7406 , 88.0845']
# ['-19.5603 , -46.9653']
# ['16.1947 , 52.1694']
# ['53.7167 , 91.4333']
# ['38.9833 , -1.85']
# ['30.3374 , 48.3032']
# ['40.6514 , -75.4342']
# ['32.4164 , -99.6803']
# ['5.2556 , -3.9292']
# ['6.73719 , 44.2797']
# ['67.1058 , -157.854']
# ['-10.9438 , 142.453']
# ['35.0494 , -106.625']
# ['45.4536 , -98.4189']
# ['22.3722 , 31.6125']
# ['20.2961 , 41.6342']
# ['9.0056 , 7.2661']
# ['-36.0678 , 146.956']
# ['31.5328 , -84.1867']
# ['57.2004 , -2.20373']
# ['16.7561 , -99.7536']
# ['5.5964 , -0.17']
# ['28.9521 , -13.6085']
# ['47.4887 , 9.55376']
# ['49.7134 , -2.22089']
# ['41.2568 , -70.0649']
# ['68.1609 , -151.696']
# ['47.7006 , 18.0064']
# ['31.609 , -97.2234']
# ['40.9698 , -124.108']
# ['25.0887 , 104.89']
# ['39.4512 , -74.5716']
# ['31.0385 , 61.4962']
# ['36.9811 , 35.2803']
# ...

# %%
len(lat_lon_airport.keys())
# Out:
# 3885

# %%
gkey = "AIzaSyBC4IyVW7a-mYc-lFFw_qXw94Vo-Rv0PJU"

# geocoordinates

target_radius = 50000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# run a request using our params dictionary
params = {
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

#TODO: uncomment this when we know what we are doing
#for key in lat_lon_airport:
key = 'AAA' 
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params['location'] = lat_lon_airport[key][0]    
response = requests.get(base_url, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()
pprint(result)
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -17.3445036,
#                                         'lng': -145.5238625},
#                            'viewport': {'northeast': {'lat': -17.3431546197085,
#                                                       'lng': -145.5225135197085},
#                                         'southwest': {'lat': -17.3458525802915,
#                                                       'lng': -145.5252114802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4da87a2a9d873bea3f914ac622c0f9805ddcb313',
#               'name': 'ANAA TOKU KAIGA',
#               'photos': [{'height': 416,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106751082921823648535/photos">MoeaHina '
#                                                 'Vivi</a>'],
# ...

# %%
latitude = result['results'][0]['geometry']['location']['lat']
latitude
# Out:
# -17.3445036

# %%
longitude = result['results'][0]['geometry']['location']['lng']
longitude
# Out:
# -145.5238625

# %%
name = result['results'][0]['name']
name
# Out:
# 'ANAA TOKU KAIGA'

# %%
latitude_hotel = []
longitude_hotel = []
name_hotel = []

params = {
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

#Set up loop
#for key in lat_lon_airport:
#    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#   params['location'] = lat_lon_airport[key][0]    
#   response = requests.get(base_url, params=params)
#   result = response.json()
#   latitude_hotel.append(result['results'][0]['geometry']['location']['lat'])
#   longitude_hotel.append(result['results'][0]['geometry']['location']['lng'])
#   name_hotel.append(result['results'][0]['name'])
#   break;

# %%
# Dependencies
import requests
import json
from pprint import pprint
import pandas as pd
import io

# %%
airport_df = pd.read_csv("./Merged_Top100.csv")
airport_df = airport_df.T
airport_df.head()
# Out:
#     0    1                     2                             3         4   \
# 1  NAM  ATL  ATLANTA GA, US (ATL)  ATLANTA GA, US (ATL) Airport  92365860
# 2  ASP  PEK     BEIJING, CN (PEK)     BEIJING, CN (PEK) Airport  77403668
# 3  EUR  LHR      LONDON, GB (LHR)      LONDON, GB (LHR) Airport  69433565
# 4  NAM  ORD  CHICAGO IL, US (ORD)  CHICAGO IL, US (ORD) Airport  66561023
# 5  ASP  HND       TOKYO, JP (HND)       TOKYO, JP (HND) Airport  62263025
#
#          5     6    7         8               9     ...          14        15  \
# 1  89292748   3.3   60   Atlanta   United States    ...     33.6558  -84.4333
# 2  73913402   4.5   84    Shunyi           China    ...     40.0724   116.583
# 3  65884143   5.1  105  Hounslow  United Kingdom    ...     51.4703  -0.45342
# 4  66904971  -0.5   85   Chicago   United States    ...     41.9796  -87.8825
# 5  64117894  -3.0   19     Tokyo           Japan    ...     35.5533   139.771
#
# ...

# %%
airport_df.to_csv("Top100Airports.csv", encoding = "utf-8")

# %%
lat = airport_df[14]

# %%
lng = airport_df[15]

# %%
coord = []

for airport in range(len(lat)):
    coord.append(lat[airport]+" , "+lng[airport])

# %%
# Testing purposes only
coord = ['33.6558 , -84.4333','40.0724 , 116.583']

# %%
gkey = ["AIzaSyANl2HVNFDn9ThOju7ELbDumiGMEAQJYds"]
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
target_radius = 1000
location_dict = {
    "bar":{"names":[],"coords":[]},
    "bus_station":{"names":[],"coords":[]},
    "car_rental":{"names":[],"coords":[]},
    "embassy":{"names":[],"coords":[]},
    "lodging":{"names":[],"coords":[]},
    "museum":{"names":[],"coords":[]},
    "night_club":{"names":[],"coords":[]},
    "restaurant":{"names":[],"coords":[]},
    "subway_station":{"names":[],"coords":[]},
    "taxi_stand":{"names":[],"coords":[]},
    "train_station":{"names":[],"coords":[]},
    "transit_station":{"names":[],"coords":[]}
}

for coordinate in coord:
    params ={
       "location": coordinate 
    }
    
    for location_type in list(location_dict.keys()):
        params['radius'] = target_radius
        params['type'] = location_type
        params['key']= gkey

        #print(params)

        response = requests.get(base_url, params=params)
        #if response:
        #    print("OK, RESPONSE")
        result = response.json()
        results_list = result['results']

        for x in results_list:
            location_dict[location_type]["coords"].append([x["geometry"]["location"]["lat"], x["geometry"]["location"]["lng"]])
            location_dict[location_type]["names"].append(x["name"])
            
#pprint(location_dict)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1538                         raise SysCallError(errno, errorcode.get(errno))
# -> 1539                 raise SysCallError(-1, "Unexpected EOF")
#    1540             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# ...

# %%
# Number of instances per category
print("Number of bars is: " + str(len(location_dict['bar']['names'])))
print("Number of bus stations is: " + str(len(location_dict['bus_station']['names'])))
print("Number of car rentals is: " + str(len(location_dict['car_rental']['names'])))
print("Number of embassies is: " + str(len(location_dict['embassy']['names'])))
print("Number of lodgings is: " + str(len(location_dict['lodging']['names'])))
print("Number of musea is: " + str(len(location_dict['museum']['names'])))
print("Number of night clubs is: " + str(len(location_dict['night_club']['names'])))
print("Number of restaurants is: " + str(len(location_dict['restaurant']['names'])))
print("Number of subway stations is: " + str(len(location_dict['subway_station']['names'])))
print("Number of taxi stands is: " + str(len(location_dict['taxi_stand']['names'])))
print("Number of train stations is: " + str(len(location_dict['train_station']['names'])))
print("Number of transit stations is: " + str(len(location_dict['transit_station']['names'])))
# Out:
# Number of bars is: 0
# Number of bus stations is: 0
# Number of car rentals is: 0
# Number of embassies is: 0
# Number of lodgings is: 0
# Number of musea is: 0
# Number of night clubs is: 0
# Number of restaurants is: 0
# Number of subway stations is: 0
# Number of taxi stands is: 0
# Number of train stations is: 0
# Number of transit stations is: 0

# %%
# Export
with io.open("all_data_within_1000_meters.json", "w", encoding="utf8") as fp:
    json.dump(location_dict, fp, indent=4, ensure_ascii=False)

# %%
# Import (testing purposes only)
#with open("data.json","r") as f:
#    data = json.load(f)
